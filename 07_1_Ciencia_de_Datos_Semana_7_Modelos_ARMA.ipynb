# %% [markdown]
# <a href="https://colab.research.google.com/github/johanordonez/CIENCIA-DE-DATOS---MAIE-2026A/blob/main/07_1_Ciencia_de_Datos_Semana_7_Modelos_ARMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Taller Práctico: Generación de Datos Sintéticos con Modelos ARMA**
# Maestría en Ingeniería Electrónica
#
# Universidad de Nariño Curso
#
# Introducción a la Ciencia de Datos
#
# Instructor: Carlos Andrés Viteri Mera
#
# En este cuaderno se analiza la serie de tiempo de los precios del índice S&P 500. El procedimiento es el siguiente:
# 1. Se extraen los rendimientos diarios de la seria.
# 2. Se verifica que el proceso sea estacionario (condición necesaria para aplicar la mayoría de modelos estocásticos clásicos).
# 3. Se ajusta un modelo ARMA (Autoregressive Moving Average) a los datos.
# 4. Se utiliza el modelo para simular (generar) 250 días de datos sintéticos que se  transforman de vuelta a precios proyectados.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
import warnings
warnings.filterwarnings('ignore')

# Configuración visual
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## **1. Obtención de Datos y Cálculo de Rendimientos**
# Se descargan los últimos 5 años de datos del S&P 500. Para que el proceso sea modelable mediante técnicas lineales y estacionarias, se trabaja con los rendimientos diarios en porcentaje y les restaremos su media para obtener un proceso de media cero.

# %%
# Descarga de datos
ticker = '^GSPC'
data = yf.download(ticker, start='2020-01-01', end='2026-03-31')
precios = data['Close'].squeeze()

# Cálculo de rendimientos porcentuales
rendimientos = precios.pct_change().dropna() * 100

# Convertir a proceso de media cero
media_rendimientos = rendimientos.mean()
rendimientos_mc = rendimientos - media_rendimientos

# Gráficas
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))
ax1.plot(precios, color='blue')
ax1.set_title('Precios Históricos S&P 500')
ax1.set_ylabel('Precio (USD)')

ax2.plot(rendimientos_mc, color='purple')
ax2.set_title('Rendimientos Diarios (Media Cero)')
ax2.set_ylabel('Rendimiento (%)')
plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # **2. Prueba de Estacionariedad**
# Un proceso es estacionario en sentido amplio (WSS) si su media y varianza son constantes en el tiempo, y su autocorrelación depende solo de la diferencia temporal. Se aplica la prueba estadística de Dickey-Fuller Aumentada (ADF), que es una prueba de hipótesis.
#
#     Hipótesis Nula (H0​): La serie de tiempo tiene NO es estacionaria.
#     Hipótesis Alternativa (H1​): La serie de tiempo ES estacionaria.
#
#     Si el valor p (p-value) es menor a 0.05, se rechaza H0​.

# %%
# Prueba ADF
resultado_adf = adfuller(rendimientos_mc)

# La hipótesis nula (H0) es: Los datos no son estacionarios
# p mide la probabilidad de que los datos observados sean obtenidos, asumiendo que
# la hipóstesis nula (H0) es verdadera. Si se obtiene p<= 0.05, los datos indican
# que hay que rechaszar la hipótesis nula.

print("--- Prueba de Dickey-Fuller Aumentada (ADF) ---")
print(f"Estadístico ADF: {resultado_adf[0]:.4f}")
print(f"Valor p (p-value): {resultado_adf[1]:.4e}")

if resultado_adf[1] < 0.05:
    print("\nConclusión: Rechazamos H0. La serie de rendimientos ES estacionaria.")
else:
    print("\nConclusión: No podemos rechazar H0. La serie NO es estacionaria.")
# Out:
# --- Prueba de Dickey-Fuller Aumentada (ADF) ---
# Estadístico ADF: -12.3071
# Valor p (p-value): 7.2292e-23
#
# Conclusión: Rechazamos H0. La serie de rendimientos ES estacionaria.

# %% [markdown]
# ## **3. Estimación del Orden del Modelo ($p$ y $q$)**
# Antes de ajustar un modelo ARMA(p,q), podemos estimar los valores adecuados para $p$ y $q$ analizando la Función de Autocorrelación (ACF) y la Función de Autocorrelación Parcial (PACF) de la serie estacionaria.
#
# ACF: Permite identificar el orden q de la parte de promedios móviles (MA). Buscamos el retardo (lag) después del cual la autocorrelación cae abruptamente a cero.
#
# PACF: Permite identificar el orden p de la parte autorregresiva (AR). Mide la correlación directa entre la variable actual y sus valores pasados, descontando el efecto de los retardos intermedios.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Autocorrelación (ACF) para identificar 'q' (MA)
plot_acf(rendimientos_mc, lags=20, ax=ax1, title="Función de Autocorrelación (ACF) - Orden q")
ax1.set_xlabel("Retardos (Lags)")

# Gráfica de Autocorrelación Parcial (PACF) para identificar 'p' (AR)
plot_pacf(rendimientos_mc, lags=20, ax=ax2, title="Autocorrelación Parcial (PACF) - Orden p", method='ywm')
ax2.set_xlabel("Retardos (Lags)")

plt.tight_layout()
plt.show()

# Análisis para los estudiantes:
# Los valores significativos (fuera de la franja sombreada de confianza) en los
# primeros retardos de la PACF nos sugieren el orden p, mientras que los de la ACF
# nos sugieren el orden q.

# %% [markdown]
# # **4. Ajuste del Modelo ARMA**
# Los procesos ARMA($p,q$) combinan una parte autorregresiva (AR) de orden $p$ y una parte de promedios móviles (MA) de orden $q$. Ajustaremos un modelo ARMA(2,2) a nuestros rendimientos de media cero para capturar su dinámica estocástica.

# %%
# Ajuste de un modelo ARMA(2,2). En statsmodels se usa ARIMA(p,d,q) con d=0.
orden_arma = (2, 0, 2)
modelo_arma = ARIMA(rendimientos_mc, order=orden_arma)
resultado_arma = modelo_arma.fit()

print(resultado_arma.summary())

# Graficamos los residuos del modelo (deberían comportarse como ruido blanco)
residuos = resultado_arma.resid

plt.figure()
plt.plot(residuos, color='red', alpha=0.7)
plt.title('Residuos del Modelo ARMA(2,2)')
plt.ylabel('Error')
plt.show()
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  ^GSPC   No. Observations:                 1567
# Model:                 ARIMA(2, 0, 2)   Log Likelihood               -2570.996
# Date:                Sat, 11 Apr 2026   AIC                           5153.993
# Time:                        19:59:28   BIC                           5186.134
# Sample:                             0   HQIC                          5165.941
#                                - 1567
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.564e-05      0.030     -0.001      1.000      -0.058       0.058
# ar.L1         -1.7326      0.017   -100.467      0.000      -1.766      -1.699
# ar.L2         -0.8762      0.016    -54.504      0.000      -0.908      -0.845
# ...

# %% [markdown]
# # **5. Generación de Datos Sintéticos y Reconstrucción de Precios**
# Utilizaremos las propiedades estadísticas aprendidas por el modelo ARMA para generar (simular) una trayectoria futura de 250 días (aproximadamente un año de negociación).
# Para volver a la escala de precios reales:
#
# Añadimos la media histórica a los rendimientos sintéticos.
# Reconstruimos los precios usando el último precio real conocido como semilla, aplicando la fórmula de interés compuesto iterativo: $P_t​=P_{t−1}​×(1+R_t​/100)$.

# %%
# 1. Simular 250 días de rendimientos de media cero
dias_simulacion = 250
rendimientos_sinteticos_mc = resultado_arma.simulate(nsimulations=dias_simulacion)

# 2. Añadir la media para obtener rendimientos proyectados reales
rendimientos_sinteticos = rendimientos_sinteticos_mc + media_rendimientos

# 3. Reconstruir los precios
precio_inicial = precios.iloc[-1]
precios_sinteticos = precio_inicial * (1 + rendimientos_sinteticos / 100).cumprod()

# Gráfica de los resultados proyectados
plt.figure(figsize=(12, 6))
# Creamos un eje de tiempo ficticio para los datos futuros
dias_futuros = np.arange(len(precios), len(precios) + dias_simulacion)

plt.plot(np.arange(len(precios)), precios.values, label='Datos Históricos Reales', color='blue')
plt.plot(dias_futuros, precios_sinteticos.values, label='Datos Sintéticos (ARMA)', color='orange', linestyle='--')

plt.title('Precios Históricos y Proyección de Datos Sintéticos Generados con ARMA')
plt.xlabel('Días')
plt.ylabel('Precio (USD)')
plt.axvline(len(precios), color='black', linestyle=':', label='Inicio de Simulación')
plt.legend()
plt.show()

# %% [markdown]
# ## **Advertencia**
# El modelo ARMA genera datos sintéticos que siguen las mismas estadísticas de los datos pasados.
#
# Sin embargo, las realizaciones del proceso ARIMA no consideran los datos inmediatamente anteriores a la predicción.

# %% [markdown]
# ## Reto 1
# Usando el modelo ARMA, genere 1000 posibles realizaciones de la serie de tiempo y grafique 20 de ellas como continuaciones de la gráfica de datos pasados.
#
# Genere un histograma de los datos sintéticos en el tiempo 250 (un año después de los datos reales). Genere también la CDF empírica de los datos sintéticos en el tiempo 250 y determine cuál es la probabilidad aproximada de que el índice se encuentre por debajo del último dato real.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF
import matplotlib.cm as cm # Importar colormap

# Establecer una semilla para la reproducibilidad
# Puedes usar cualquier número entero como semilla
semilla_personalizada = 42
random.seed(semilla_personalizada)

# SIMULAR 1000 REALIZACIONES
# Inicializamos una lista para almacenar las simulaciones de precios sintéticos
all_precios_sinteticos = []

dias_simulacion = 250 # Definir fuera del bucle ya que es constante

for i in range(1000):
    # 1. Simular 250 días de rendimientos de media cero
    # Es importante que cada simulación sea independiente si queremos 1000 realizaciones distintas.
    # El `resultado_arma.simulate()` genera una nueva secuencia aleatoria cada vez que se llama.
    rendimientos_sinteticos_mc_current = resultado_arma.simulate(nsimulations=dias_simulacion)

    # 2. Añadir la media para obtener rendimientos proyectados reales
    rendimientos_sinteticos_current = rendimientos_sinteticos_mc_current + media_rendimientos

    # 3. Reconstruir los precios
    precio_inicial = precios.iloc[-1]
    precios_sinteticos_current = precio_inicial * (1 + rendimientos_sinteticos_current / 100).cumprod()
    all_precios_sinteticos.append(precios_sinteticos_current)


# Gráfica de los resultados proyectados (20 primeras realizaciones)
plt.figure(figsize=(12, 6))
# Creamos un eje de tiempo ficticio para los datos futuros
dias_futuros = np.arange(len(precios), len(precios) + dias_simulacion)

plt.plot(np.arange(len(precios)), precios.values, label='Datos Históricos Reales', color='blue')

# Definir una paleta de colores para las simulaciones
colores = cm.get_cmap('viridis', 20) # 'viridis' es un buen colormap, 20 colores para 20 líneas

# Graficar las primeras 20 realizaciones sintéticas completas con diferentes colores
for i in range(20):
    # Asignar un color diferente a cada línea
    plt.plot(dias_futuros, all_precios_sinteticos[i].values, color=colores(i), linestyle='--', alpha=0.7)

# Agregamos una única leyenda para 'Realizaciones Sintéticas' para no saturar la leyenda con 20 entradas
plt.plot([], [], color='gray', linestyle='--', alpha=0.7, label='20 Realizaciones Sintéticas (ARMA)') # Línea fantasma para la leyenda

plt.title('Precios Históricos y Proyección de Datos Sintéticos Generados con ARMA')
plt.xlabel('Días')
plt.ylabel('Precio (USD)')
plt.axvline(len(precios), color='black', linestyle=':', label='Inicio de Simulación')
plt.legend()
plt.show()

# --- RETO 1: Parte 2 --- #

# Extraer los precios del día 250 de cada simulación
precios_dia_250 = [simulacion.iloc[-1] for simulacion in all_precios_sinteticos]

# 1. Histograma de los datos sintéticos en el tiempo 250
plt.figure(figsize=(10, 6))
plt.hist(precios_dia_250, bins=50, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histograma de Precios Sintéticos en el Día 250')
plt.xlabel('Precio (USD)')
plt.ylabel('Densidad de Probabilidad')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# 2. CDF empírica de los datos sintéticos en el tiempo 250
ecdf = ECDF(precios_dia_250)

plt.figure(figsize=(10, 6))
plt.plot(ecdf.x, ecdf.y, drawstyle='steps-post', color='green', linewidth=2)
plt.title('Función de Distribución Acumulada (CDF) Empírica en el Día 250')
plt.xlabel('Precio (USD)')
plt.ylabel('Probabilidad Acumulada')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# 3. Probabilidad aproximada de que el índice se encuentre por debajo del último dato real
ultimo_precio_real = precios.iloc[-1]
probabilidad_debajo = ecdf(ultimo_precio_real)

print(f"\nÚltimo precio real conocido: {ultimo_precio_real:.2f} USD")
print(f"Probabilidad de que el índice sintético en el día 250 esté por debajo de {ultimo_precio_real:.2f} USD: {probabilidad_debajo:.4f}")
# Out:
# Último precio real conocido: 6343.72 USD
# Probabilidad de que el índice sintético en el día 250 esté por debajo de 6343.72 USD: 0.2620

# %% [markdown]
# ## Reto 2
#
# Utilice la misma metodología descrita anteriormente para modelar cualquier serie de tiempo de su interés como un proceso ARMA y generar datos sintéticos.
#
# Si los datos $x$ no son estacionarios puede utilizar algunas de las siguientes transformaciones:
# 1. Trabajar con la serie de tiempo $y=\log(x)$
# 2. Normalizar la serie para que tenga valor medio cero $y=x-\mathbf{E}[x]$
# 3. Trabajar con la serie diferencia $y(n)=x(n)-x(n-1)$ o con la serie de cambio porcentual mostrada anteriormente

# %%
# Descarga de datos
ticker = 'USDCOP=X'
dataD = yf.download(ticker, start='2010-01-01', end='2026-03-31')
preciosD = dataD['Close'].squeeze()

# Cálculo de rendimientos porcentuales
rendimientosD = preciosD.pct_change().dropna() * 100

# Convertir a proceso de media cero
media_rendimientosD = rendimientosD.mean()
rendimientos_mcD = rendimientosD - media_rendimientosD

# Gráficas
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))
ax1.plot(preciosD, color='blue')
ax1.set_title('Cambio del valor Dolar en peso colombiano historico')
ax1.set_ylabel('Precio (COP)')

ax2.plot(rendimientos_mcD, color='purple')
ax2.set_title('Rendimientos Diarios (Media Cero)')
ax2.set_ylabel('Rendimiento (%)')
plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Descarga de datos
ticker = 'USDCOP=X'
dataD = yf.download(ticker, start='2017-01-01', end='2026-03-31')
preciosD = dataD['Close'].squeeze()

# Cálculo de rendimientos porcentuales
rendimientosD = preciosD.pct_change().dropna() * 100

# --- Manejo de Outliers en Rendimientos (Reemplazo con valor anterior) ---
# Calcular Q1, Q3 e IQR para los rendimientos
Q1 = rendimientosD.quantile(0.25)
Q3 = rendimientosD.quantile(0.75)
IQR = Q3 - Q1

# Definir límites para la detección de outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identificar y reemplazar outliers con NaN
# Usamos .copy() para evitar SettingWithCopyWarning
rendimientosD_handled = rendimientosD.copy()
rendimientosD_handled[(rendimientosD_handled < lower_bound) | (rendimientosD_handled > upper_bound)] = np.nan

# Reemplazar NaN con el valor anterior válido (forward-fill)
# Primero, aseguramos que el primer valor no sea NaN, si lo es, lo rellenamos hacia atrás.
if pd.isna(rendimientosD_handled.iloc[0]):
    rendimientosD_handled.iloc[0] = rendimientosD_handled.bfill().iloc[0]
rendimientosD_filled = rendimientosD_handled.ffill()

# Opcional: Imprimir cuántos outliers fueron identificados y manejados
num_outliers_identified = rendimientosD.size - rendimientosD_handled.count()
print(f"Se identificaron y manejaron {int(num_outliers_identified)} outliers en la serie de rendimientos (reemplazados con el valor anterior).")

# Usar la serie manejada para los cálculos posteriores
rendimientosD = rendimientosD_filled
# ----------------------------------------------------------------------

# Convertir a proceso de media cero
media_rendimientosD = rendimientosD.mean()
rendimientos_mcD = rendimientosD - media_rendimientosD

# Gráficas
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))
ax1.plot(preciosD, color='blue')
ax1.set_title('Cambio del valor Dolar en peso colombiano historico')
ax1.set_ylabel('Precio (COP)')

ax2.plot(rendimientos_mcD, color='purple')
ax2.set_title('Rendimientos Diarios (Media Cero)')
ax2.set_ylabel('Rendimiento (%)')
plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Se identificaron y manejaron 73 outliers en la serie de rendimientos (reemplazados con el valor anterior).

# %%
# Prueba ADF
resultado_adfD = adfuller(rendimientos_mcD)

# La hipótesis nula (H0) es: Los datos no son estacionarios
# p mide la probabilidad de que los datos observados sean obtenidos, asumiendo que
# la hipóstesis nula (H0) es verdadera. Si se obtiene p<= 0.05, los datos indican
# que hay que rechaszar la hipótesis nula.

print("--- Prueba de Dickey-Fuller Aumentada (ADF) ---")
print(f"Estadístico ADF: {resultado_adfD[0]:.4f}")
print(f"Valor p (p-value): {resultado_adfD[1]:.4e}")

if resultado_adfD[1] < 0.05:
    print("\nConclusión: Rechazamos H0. La serie de rendimientos ES estacionaria.")
else:
    print("\nConclusión: No podemos rechazar H0. La serie NO es estacionaria.")
# Out:
# --- Prueba de Dickey-Fuller Aumentada (ADF) ---
# Estadístico ADF: -10.6836
# Valor p (p-value): 3.8837e-19
#
# Conclusión: Rechazamos H0. La serie de rendimientos ES estacionaria.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Autocorrelación (ACF) para identificar 'q' (MA)
plot_acf(rendimientos_mcD, lags=20, ax=ax1, title="Función de Autocorrelación (ACF) - Orden q")
ax1.set_xlabel("Retardos (Lags)")

# Gráfica de Autocorrelación Parcial (PACF) para identificar 'p' (AR)
plot_pacf(rendimientos_mcD, lags=20, ax=ax2, title="Autocorrelación Parcial (PACF) - Orden p", method='ywm')
ax2.set_xlabel("Retardos (Lags)")

plt.tight_layout()
plt.show()

# %%
# Ajuste de un modelo ARMA(2,2). En statsmodels se usa ARIMA(p,d,q) con d=0.
orden_armaD = (2, 0, 2) # aplicar un filtro posible para hacerlo estacionario
modelo_armaD = ARIMA(rendimientos_mcD, order=orden_armaD)
resultado_armaD = modelo_armaD.fit()

print(resultado_armaD.summary())

# Graficamos los residuos del modelo (deberían comportarse como ruido blanco)
residuosD = resultado_armaD.resid

plt.figure()
plt.plot(residuosD, color='red', alpha=0.7)
plt.title('Residuos del Modelo ARMA(2,2)')
plt.ylabel('Error')
plt.show()
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:               USDCOP=X   No. Observations:                 2404
# Model:                 ARIMA(2, 0, 2)   Log Likelihood               -3036.655
# Date:                Sat, 11 Apr 2026   AIC                           6085.309
# Time:                        21:26:47   BIC                           6120.019
# Sample:                             0   HQIC                          6097.936
#                                - 2404
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.632e-05      0.018     -0.001      0.999      -0.036       0.036
# ar.L1         -0.0452      0.133     -0.340      0.734      -0.306       0.216
# ar.L2         -0.7673      0.114     -6.705      0.000      -0.992      -0.543
# ...

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF
import matplotlib.cm as cm # Importar colormap

# Establecer una semilla para la reproducibilidad
# Puedes usar cualquier número entero como semilla
semilla_personalizada = 42
random.seed(semilla_personalizada)

# SIMULAR 1000 REALIZACIONES
# Inicializamos una lista para almacenar las simulaciones de precios sintéticos para USDCOP
all_precios_sinteticosD = []

dias_simulacionD = 250 # Definir fuera del bucle ya que es constante

for i in range(1000):
    # 1. Simular 250 días de rendimientos de media cero para USDCOP
    rendimientos_sinteticos_mc_current_D = resultado_armaD.simulate(nsimulations=dias_simulacionD)

    # 2. Añadir la media para obtener rendimientos proyectados reales para USDCOP
    rendimientos_sinteticos_current_D = rendimientos_sinteticos_mc_current_D + media_rendimientosD

    # 3. Reconstruir los precios para USDCOP
    precio_inicial_D = preciosD.iloc[-1]
    precios_sinteticos_current_D = precio_inicial_D * (1 + rendimientos_sinteticos_current_D / 100).cumprod()
    all_precios_sinteticosD.append(precios_sinteticos_current_D)


# Gráfica de los resultados proyectados (20 primeras realizaciones)
plt.figure(figsize=(12, 6))
# Creamos un eje de tiempo ficticio para los datos futuros
dias_futuros_D = np.arange(len(preciosD), len(preciosD) + dias_simulacionD)

plt.plot(np.arange(len(preciosD)), preciosD.values, label='Datos Históricos Reales (USDCOP)', color='blue')

# Definir una paleta de colores para las simulaciones
colores = cm.get_cmap('viridis', 20) # 'viridis' es un buen colormap, 20 colores para 20 líneas

# Graficar las primeras 20 realizaciones sintéticas completas con diferentes colores
for i in range(20):
    # Asignar un color diferente a cada línea
    plt.plot(dias_futuros_D, all_precios_sinteticosD[i].values, color=colores(i), linestyle='--', alpha=0.7)

# Agregamos una única leyenda para 'Realizaciones Sintéticas' para no saturar la leyenda con 20 entradas
plt.plot([], [], color='gray', linestyle='--', alpha=0.7, label='20 Realizaciones Sintéticas (ARMA) USDCOP') # Línea fantasma para la leyenda

plt.title('Precios Históricos y Proyección de Datos Sintéticos Generados con ARMA (USDCOP)')
plt.xlabel('Días')
plt.ylabel('Precio (COP)')
plt.axvline(len(preciosD), color='black', linestyle=':', label='Inicio de Simulación')
plt.legend()
plt.show()

# --- Reto 2: Parte 2 --- #

# Extraer los precios del día 250 de cada simulación
precios_dia_250_D = [simulacion.iloc[-1] for simulacion in all_precios_sinteticosD]

# 1. Histograma de los datos sintéticos en el tiempo 250
plt.figure(figsize=(10, 6))
plt.hist(precios_dia_250_D, bins=50, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histograma de Precios Sintéticos en el Día 250 (USDCOP)')
plt.xlabel('Precio (COP)')
plt.ylabel('Densidad de Probabilidad')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# 2. CDF empírica de los datos sintéticos en el tiempo 250
ecdf_D = ECDF(precios_dia_250_D)

plt.figure(figsize=(10, 6))
plt.plot(ecdf_D.x, ecdf_D.y, drawstyle='steps-post', color='green', linewidth=2)
plt.title('Función de Distribución Acumulada (CDF) Empírica en el Día 250 (USDCOP)')
plt.xlabel('Precio (COP)')
plt.ylabel('Probabilidad Acumulada')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# 3. Probabilidad aproximada de que el índice se encuentre por debajo del último dato real
ultimo_precio_real_D = preciosD.iloc[-1]
probabilidad_debajo_D = ecdf_D(ultimo_precio_real_D)

print(f"\nÚltimo precio real conocido (USDCOP): {ultimo_precio_real_D:.2f} COP")
print(f"Probabilidad de que el índice sintético en el día 250 esté por debajo de {ultimo_precio_real_D:.2f} COP: {probabilidad_debajo_D:.4f}")
# Out:
# Último precio real conocido (USDCOP): 3672.28 COP
# Probabilidad de que el índice sintético en el día 250 esté por debajo de 3672.28 COP: 0.8550
